# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import time
import sqlite3
from sklearn.cluster import KMeans

sns.set(rc={'figure.figsize': [16, 16]}, font_scale=1)

# %%
df=pd.read_csv('IMDB_Movies.csv')
df
# Out:
#                                             Titles  Production Year  \
# 0                         The Shawshank Redemption             1994
# 1                                    The Godfather             1972
# 2                                  The Dark Knight             2008
# 3    The Lord of the Rings: The Return of the King             2003
# 4                                 Schindler's List             1993
# ..                                             ...              ...
# 995                                        Sabrina             1954
# 996                          From Here to Eternity             1953
# 997                Snow White and the Seven Dwarfs             1937
# 998                                   The 39 Steps             1935
# 999                              The Invisible Man             1933
#
#     Certificates Runtimes                        Genres  Rates  \
# 0              R  142 min                         Drama    9.3
# ...

# %%
df.drop(['Votes'],axis=1,inplace=True)

# %% [markdown]
# # Display Top 10 Row of the Dataset

# %%
df.head(10)
# Out:
#                                           Titles  Production Year  \
# 0                       The Shawshank Redemption             1994
# 1                                  The Godfather             1972
# 2                                The Dark Knight             2008
# 3  The Lord of the Rings: The Return of the King             2003
# 4                               Schindler's List             1993
# 5                          The Godfather Part II             1974
# 6                                   12 Angry Men             1957
# 7                                       Jai Bhim             2021
# 8                                   Pulp Fiction             1994
# 9                                      Inception             2010
#
#   Certificates Runtimes                     Genres  Rates  \
# 0            R  142 min                      Drama    9.3
# 1            R  175 min               Crime, Drama    9.2
# 2        PG-13  152 min       Action, Crime, Drama    9.0
# ...

# %% [markdown]
# # Display Last 10 Row of the Dataset

# %%
df.tail(10)
# Out:
#                               Titles  Production Year Certificates Runtimes  \
# 990                        Repulsion             1965          NaN  105 min
# 991                        The Birds             1963          NaN  119 min
# 992           Breakfast at Tiffany's             1961          NaN  115 min
# 993              Eyes Without a Face             1960          NaN   90 min
# 994            Rebel Without a Cause             1955          NaN  111 min
# 995                          Sabrina             1954          NaN  113 min
# 996            From Here to Eternity             1953          NaN  118 min
# 997  Snow White and the Seven Dwarfs             1937          NaN   83 min
# 998                     The 39 Steps             1935          NaN   86 min
# 999                The Invisible Man             1933          NaN   71 min
#
#                            Genres  Rates  \
# 990       Drama, Horror, Thriller    7.6
# 991        Drama, Horror, Mystery    7.6
# ...

# %% [markdown]
# # 3.find shape of our dataset (number of Row and number of columns)

# %%
df.shape
# Out:
# (1000, 8)

# %%
print("Number of columns:",df.shape[0])
print("Number of Rows:",df.shape[1])
# Out:
# Number of columns: 1000
# Number of Rows: 8

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titles           1000 non-null   object
#  1   Production Year  1000 non-null   int64
#  2   Certificates     988 non-null    object
#  3   Runtimes         1000 non-null   object
#  4   Genres           1000 non-null   object
#  5   Rates            1000 non-null   float64
#  6   Stories          1000 non-null   object
#  7   Directors        1000 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['Titles'].unique()
# Out:
# array(['The Shawshank Redemption', 'The Godfather', 'The Dark Knight',
#        'The Lord of the Rings: The Return of the King',
#        "Schindler's List", 'The Godfather Part II', '12 Angry Men',
#        'Jai Bhim', 'Pulp Fiction', 'Inception',
#        'The Lord of the Rings: The Two Towers', 'Fight Club',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'Forrest Gump', 'The Good, the Bad and the Ugly',
#        'Soorarai Pottru', 'The Matrix', 'Goodfellas',
#        'Star Wars: Episode V - The Empire Strikes Back',
#        "One Flew Over the Cuckoo's Nest", 'Top Gun: Maverick',
#        'Interstellar', 'City of God', 'Spirited Away',
#        'Saving Private Ryan', 'The Green Mile', 'Life Is Beautiful',
#        'Se7en', 'Terminator 2: Judgment Day', 'The Silence of the Lambs',
#        'Star Wars', 'Harakiri', 'Seven Samurai', "It's a Wonderful Life",
#        'Kaithi', 'Asuran', 'Vikram', '96', 'Parasite', 'Whiplash',
# ...

# %% [markdown]
# <b> the Titles count :996<b>

# %%
df['Titles'].nunique()
# Out:
# 996

# %% [markdown]
# # <b> the most height Drishyam  & Beauty and the Beast<b>

# %%
df['Titles'].value_counts()
# Out:
# Scarface                           2
# The Girl with the Dragon Tattoo    2
# Beauty and the Beast               2
# Drishyam                           2
# Spartacus                          1
#                                   ..
# The Umbrellas of Cherbourg         1
# The Lion in Winter                 1
# The Way He Looks                   1
# The Grand Budapest Hotel           1
# Oldboy                             1
# Name: Titles, Length: 996, dtype: int64

# %%
df['Production Year'].describe()
# Out:
# count    1000.000000
# mean     1991.242000
# std        23.931029
# min      1920.000000
# 25%      1975.000000
# 50%      1999.000000
# 75%      2010.000000
# max      2022.000000
# Name: Production Year, dtype: float64

# %%
df['Genres'].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Crime, Drama, Mystery', 'Action, Adventure, Sci-Fi',
#        'Drama, Romance', 'Adventure, Western', 'Action, Sci-Fi',
#        'Biography, Crime, Drama', 'Action, Adventure, Fantasy',
#        'Action, Drama', 'Adventure, Drama, Sci-Fi',
#        'Animation, Adventure, Family', 'Drama, War',
#        'Crime, Drama, Fantasy', 'Comedy, Drama, Romance',
#        'Crime, Drama, Thriller', 'Action, Drama, Mystery',
#        'Drama, Family, Fantasy', 'Action, Crime, Thriller',
#        'Action, Thriller', 'Comedy, Drama, Thriller', 'Drama, Music',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Sci-Fi',
#        'Biography, Drama, Music', 'Animation, Adventure, Drama',
#        'Animation, Drama, War', 'Adventure, Comedy, Sci-Fi',
#        'Drama, Mystery, War', 'Horror, Sci-Fi', 'Western',
#        'Horror, Mystery, Thriller', 'Mystery, Thriller',
# ...

# %% [markdown]
# <b> Genres count :202<b>

# %%
df['Genres'].nunique()
# Out:
# 202

# %% [markdown]
# <b> the most Genres is Drama &Drama, Romance&Comedy, Drama<b>

# %%
df['Genres'].value_counts()
# Out:
# Drama                           83
# Drama, Romance                  36
# Comedy, Drama                   35
# Comedy, Drama, Romance          34
# Action, Crime, Drama            31
#                                 ..
# Adventure, Drama, Family         1
# Action, Adventure, War           1
# Crime, Drama, Fantasy            1
# Drama, Thriller, Western         1
# Adventure, Comedy, Film-Noir     1
# Name: Genres, Length: 202, dtype: int64

# %%
df['Rates'].describe()
# Out:
# count    1000.000000
# mean        7.963100
# std         0.276414
# min         7.600000
# 25%         7.700000
# 50%         7.900000
# 75%         8.100000
# max         9.300000
# Name: Rates, dtype: float64

# %%
df['Stories'].unique()
# Out:
# array(['Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#        'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.',
#        'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
#        "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
#        'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.',
# ...

# %% [markdown]
# <b> the Stories count is :1000<b>

# %%
df['Stories'].nunique()
# Out:
# 1000

# %%
df['Stories'].value_counts()
# Out:
# In post-war Italy, a working-class man's bicycle is stolen, endangering his efforts to find work. He and his son set out to find it.                                                                    1
# A toon-hating detective is a cartoon rabbit's only hope to prove his innocence when he is accused of murder.                                                                                            1
# The Incredibles family takes on a new mission which involves a change in family roles: Bob Parr (Mr. Incredible) must manage the house while his wife Helen (Elastigirl) goes out to save the world.    1
# A man who loves games and theater invites his wife's lover to meet him, setting up a battle of wits with potentially deadly results.                                                                    1
# ...

# %%
df['Directors'].unique()
# Out:
# array(['Frank Darabont', 'Francis Ford Coppola', 'Christopher Nolan',
#        'Peter Jackson', 'Steven Spielberg', 'Sidney Lumet',
#        'T.J. Gnanavel', 'Quentin Tarantino', 'David Fincher',
#        'Robert Zemeckis', 'Sergio Leone', 'Sudha Kongara',
#        'Lana Wachowski', 'Martin Scorsese', 'Irvin Kershner',
#        'Milos Forman', 'Joseph Kosinski', 'Fernando Meirelles',
#        'Hayao Miyazaki', 'Roberto Benigni', 'James Cameron',
#        'Jonathan Demme', 'George Lucas', 'Masaki Kobayashi',
#        'Akira Kurosawa', 'Frank Capra', 'Lokesh Kanagaraj', 'Vetrimaaran',
#        'C. Prem Kumar', 'Bong Joon Ho', 'Damien Chazelle',
#        'Olivier Nakache', 'Shoojit Sircar', 'Roman Polanski',
#        'Ridley Scott', 'Tony Kaye', 'Bryan Singer', 'Luc Besson',
#        'Roger Allers', 'Giuseppe Tornatore', 'Isao Takahata',
#        'Alfred Hitchcock', 'Michael Curtiz', 'Charles Chaplin',
#        'Nadine Labaki', 'Todd Phillips', 'Makoto Shinkai',
# ...

# %% [markdown]
# <b>the Directors count: 553<b>

# %%
df['Directors'].nunique()
# Out:
# 553

# %% [markdown]
# <b> the most Directors is Alfred Hitchcock and Steven Spielberg and Akira Kurosawa<b>

# %%
df['Directors'].value_counts()
# Out:
# Steven Spielberg        13
# Alfred Hitchcock        13
# Akira Kurosawa          12
# Martin Scorsese         10
# Hayao Miyazaki          10
#                         ..
# Zaza Urushadze           1
# Elem Klimov              1
# James Foley              1
# Christophe Barratier     1
# Hannes Holm              1
# Name: Directors, Length: 553, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titles           1000 non-null   object
#  1   Production Year  1000 non-null   int64
#  2   Certificates     988 non-null    object
#  3   Runtimes         1000 non-null   object
#  4   Genres           1000 non-null   object
#  5   Rates            1000 non-null   float64
#  6   Stories          1000 non-null   object
#  7   Directors        1000 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# # cleaning

# %% [markdown]
# <b>converted the data to numerical</b>

# %%
int(df['Runtimes'].iloc[90].split(' ')[0])
# Out:
# 88

# %%
df['Runtimes']=df['Runtimes'].apply(lambda x:int(x.split(' ')[0]))

# %%
df
# Out:
#                                             Titles  Production Year  \
# 0                         The Shawshank Redemption             1994
# 1                                    The Godfather             1972
# 2                                  The Dark Knight             2008
# 3    The Lord of the Rings: The Return of the King             2003
# 4                                 Schindler's List             1993
# ..                                             ...              ...
# 995                                        Sabrina             1954
# 996                          From Here to Eternity             1953
# 997                Snow White and the Seven Dwarfs             1937
# 998                                   The 39 Steps             1935
# 999                              The Invisible Man             1933
#
#     Certificates  Runtimes                        Genres  Rates  \
# 0              R       142                         Drama    9.3
# ...

# %%
df
# Out:
#                                             Titles  Production Year  \
# 0                         The Shawshank Redemption             1994
# 1                                    The Godfather             1972
# 2                                  The Dark Knight             2008
# 3    The Lord of the Rings: The Return of the King             2003
# 4                                 Schindler's List             1993
# ..                                             ...              ...
# 995                                        Sabrina             1954
# 996                          From Here to Eternity             1953
# 997                Snow White and the Seven Dwarfs             1937
# 998                                   The 39 Steps             1935
# 999                              The Invisible Man             1933
#
#     Certificates  Runtimes                        Genres  Rates  \
# 0              R       142                         Drama    9.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titles           1000 non-null   object
#  1   Production Year  1000 non-null   int64
#  2   Certificates     988 non-null    object
#  3   Runtimes         1000 non-null   int64
#  4   Genres           1000 non-null   object
#  5   Rates            1000 non-null   float64
#  6   Stories          1000 non-null   object
#  7   Directors        1000 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Titles, Production Year, Certificates, Runtimes, Genres, Rates, Stories, Directors]
# Index: []

# %%
cat_feat1 = ['Titles', 'Certificates', 'Genres', 'Stories', 'Directors','Runtimes']
              
for col in cat_feat1:
        print(f'Categorical feature name: {col}')
        print(df[col].unique())
        print('-'*13)
        print(df[col].value_counts())
        print('-'*50)
# Out:
# Categorical feature name: Titles
# ['The Shawshank Redemption' 'The Godfather' 'The Dark Knight'
#  'The Lord of the Rings: The Return of the King' "Schindler's List"
#  'The Godfather Part II' '12 Angry Men' 'Jai Bhim' 'Pulp Fiction'
#  'Inception' 'The Lord of the Rings: The Two Towers' 'Fight Club'
#  'The Lord of the Rings: The Fellowship of the Ring' 'Forrest Gump'
#  'The Good, the Bad and the Ugly' 'Soorarai Pottru' 'The Matrix'
#  'Goodfellas' 'Star Wars: Episode V - The Empire Strikes Back'
#  "One Flew Over the Cuckoo's Nest" 'Top Gun: Maverick' 'Interstellar'
#  'City of God' 'Spirited Away' 'Saving Private Ryan' 'The Green Mile'
#  'Life Is Beautiful' 'Se7en' 'Terminator 2: Judgment Day'
#  'The Silence of the Lambs' 'Star Wars' 'Harakiri' 'Seven Samurai'
#  "It's a Wonderful Life" 'Kaithi' 'Asuran' 'Vikram' '96' 'Parasite'
#  'Whiplash' 'The Intouchables' 'Sardar Udham' 'The Prestige'
#  'The Departed' 'The Pianist' 'Gladiator' 'American History X'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titles           1000 non-null   object
#  1   Production Year  1000 non-null   int64
#  2   Certificates     988 non-null    object
#  3   Runtimes         1000 non-null   int64
#  4   Genres           1000 non-null   object
#  5   Rates            1000 non-null   float64
#  6   Stories          1000 non-null   object
#  7   Directors        1000 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB

# %%
Num_feat1 = ['Production Year',  'Rates']
              
for col in Num_feat1:
        print(f'Numerical feature name: {col}')
        print(df[col].describe())
        print('-'*13)
# Out:
# Numerical feature name: Production Year
# count    1000.000000
# mean     1991.242000
# std        23.931029
# min      1920.000000
# 25%      1975.000000
# 50%      1999.000000
# 75%      2010.000000
# max      2022.000000
# Name: Production Year, dtype: float64
# -------------
# Numerical feature name: Rates
# count    1000.000000
# mean        7.963100
# std         0.276414
# min         7.600000
# 25%         7.700000
# 50%         7.900000
# 75%         8.100000
# max         9.300000
# Name: Rates, dtype: float64
# -------------

# %% [markdown]
# # Check missing value

# %%
df.isnull().sum()*100/1000
# Out:
# Titles             0.0
# Production Year    0.0
# Certificates       1.2
# Runtimes           0.0
# Genres             0.0
# Rates              0.0
# Stories            0.0
# Directors          0.0
# dtype: float64

# %% [markdown]
# # Check For Duplicate Data

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# # Get Overall Statistics About The DataFrame

# %%
df.describe()
# Out:
#        Production Year     Runtimes        Rates
# count      1000.000000  1000.000000  1000.000000
# mean       1991.242000   123.690000     7.963100
# std          23.931029    28.457226     0.276414
# min        1920.000000    45.000000     7.600000
# 25%        1975.000000   103.000000     7.700000
# 50%        1999.000000   120.000000     7.900000
# 75%        2010.000000   138.000000     8.100000
# max        2022.000000   321.000000     9.300000

# %% [markdown]
# # 9. Display Title of The Movie Having Runtime Greater Than or equal to 180 Minutes

# %%
df.columns
# Out:
# Index(['Titles', 'Production Year', 'Certificates', 'Runtimes', 'Genres',
#        'Rates', 'Stories', 'Directors'],
#       dtype='object')

# %%
df[df['Runtimes']>=180]['Titles']
# Out:
# 3      The Lord of the Rings: The Return of the King
# 4                                   Schindler's List
# 5                              The Godfather Part II
# 25                                    The Green Mile
# 32                                     Seven Samurai
# 65                                 Avengers: Endgame
# 115                      Once Upon a Time in America
# 122                               Lawrence of Arabia
# 147                               Bhaag Milkha Bhaag
# 149                               Gangs of Wasseypur
# 158                          The Wolf of Wall Street
# 202                               Gone with the Wind
# 254                                           Swades
# 257                                   Dil Chahta Hai
# 264                Lagaan: Once Upon a Time in India
# 288                                           Gandhi
# 289                              Fanny and Alexander
# 293                                  The Deer Hunter
# ...

# %% [markdown]
# # 12. Find The Average Rating For Each Director

# %%
df.groupby('Directors')['Rates'].mean().sort_values()
# Out:
# Directors
# Jonathan Levine     7.60
# Aneesh Chaganty     7.60
# John Lee Hancock    7.60
# Francis Veber       7.60
# Tony Bancroft       7.60
#                     ...
# Lana Wachowski      8.70
# Sudha Kongara       8.70
# Irvin Kershner      8.70
# T.J. Gnanavel       8.90
# Frank Darabont      8.95
# Name: Rates, Length: 553, dtype: float64

# %% [markdown]
# # 13. Display Top 10 Lengthy Movies Title and Runtime

# %%
df.nlargest(10,'Runtimes')['Titles']
# Out:
# 149                   Gangs of Wasseypur
# 360         Zack Snyder's Justice League
# 678                               Hamlet
# 202                   Gone with the Wind
# 115          Once Upon a Time in America
# 264    Lagaan: Once Upon a Time in India
# 570                 The Ten Commandments
# 122                   Lawrence of Arabia
# 311                              Ben-Hur
# 630                         The Irishman
# Name: Titles, dtype: object

# %% [markdown]
# # 14. Display Number of Movies Per Year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titles           1000 non-null   object
#  1   Production Year  1000 non-null   int64
#  2   Certificates     988 non-null    object
#  3   Runtimes         1000 non-null   int64
#  4   Genres           1000 non-null   object
#  5   Rates            1000 non-null   float64
#  6   Stories          1000 non-null   object
#  7   Directors        1000 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB

# %%
df['Production Year'].value_counts()
# Out:
# 2004    32
# 2014    32
# 2016    28
# 2013    27
# 2019    26
#         ..
# 1921     1
# 1926     1
# 1930     1
# 1936     1
# 1920     1
# Name: Production Year, Length: 101, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titles           1000 non-null   object
#  1   Production Year  1000 non-null   int64
#  2   Certificates     988 non-null    object
#  3   Runtimes         1000 non-null   int64
#  4   Genres           1000 non-null   object
#  5   Rates            1000 non-null   float64
#  6   Stories          1000 non-null   object
#  7   Directors        1000 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # Database

# %%
import sqlite3
connection=sqlite3.connect('IMDB.db')
c=connection.cursor()

c.execute('CREATE TABLE IF NOT EXISTS CARS (Titles text, Production Year number, Certificates text, Runtimes number, Genres text,Rates number,Stories text,Directors text )')
connection.commit()

# %%
df.to_sql('iMDB', connection, index=False, if_exists='replace')
# Out:
# C:\Users\ELPOP\anaconda3\lib\site-packages\pandas\core\generic.py:2779: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
df
# Out:
#                                             Titles  Production Year  \
# 0                         The Shawshank Redemption             1994
# 1                                    The Godfather             1972
# 2                                  The Dark Knight             2008
# 3    The Lord of the Rings: The Return of the King             2003
# 4                                 Schindler's List             1993
# ..                                             ...              ...
# 995                                        Sabrina             1954
# 996                          From Here to Eternity             1953
# 997                Snow White and the Seven Dwarfs             1937
# 998                                   The 39 Steps             1935
# 999                              The Invisible Man             1933
#
#     Certificates  Runtimes                        Genres  Rates  \
# 0              R       142                         Drama    9.3
# ...

# %%
sns.displot(df['Rates'], kde=False, bins=30, color='m')

# %%
sns.kdeplot(df['Rates'], shade=True, color='m')
# Out:
# <AxesSubplot:xlabel='Rates', ylabel='Density'>

# %%
sns.displot(df['Runtimes'], kde=True, bins=30, color='m')

# %%
sns.displot(df['Production Year'], kde=True, bins=30, color='m')

# %% [markdown]
# <b> increase Production Year increase Rates<b>

# %%
sns.jointplot(x='Production Year', y='Rates', data=df, color='m')

# %% [markdown]
# <b> the most Certificates is R<b>

# %%
sns.countplot(y='Certificates', data=df, palette='viridis')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Certificates'>

# %%
sns.countplot(y='Genres', data=df, palette='viridis')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Genres'>

# %%
sns.countplot(y='Directors', data=df, palette='viridis')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Directors'>

# %%
df.isnull().sum()
# Out:
# Titles              0
# Production Year     0
# Certificates       12
# Runtimes            0
# Genres              0
# Rates               0
# Stories             0
# Directors           0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
impute=SimpleImputer(strategy='most_frequent')
df['Certificates']=impute.fit_transform(df[['Certificates']])
impute.statistics_
# Out:
# array(['R'], dtype=object)

# %%
df.drop(['Titles','Stories','Runtimes'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Production Year    0
# Certificates       0
# Genres             0
# Rates              0
# Directors          0
# dtype: int64

# %%
df = pd.get_dummies(df, columns=['Certificates', 'Genres',   'Directors'] ,
        drop_first=True)
df
# Out:
#      Production Year  Rates  Certificates_G  Certificates_GP  \
# 0               1994    9.3               0                0
# 1               1972    9.2               0                0
# 2               2008    9.0               0                0
# 3               2003    9.0               0                0
# 4               1993    9.0               0                0
# ..               ...    ...             ...              ...
# 995             1954    7.6               0                0
# 996             1953    7.6               0                0
# 997             1937    7.6               0                0
# 998             1935    7.6               0                0
# 999             1933    7.6               0                0
#
#      Certificates_M/PG  Certificates_NC-17  Certificates_Not Rated  \
# 0                    0                   0                       0
# 1                    0                   0                       0
# ...

# %%
x = df.drop('Rates', axis=1)
x
# Out:
#      Production Year  Certificates_G  Certificates_GP  Certificates_M/PG  \
# 0               1994               0                0                  0
# 1               1972               0                0                  0
# 2               2008               0                0                  0
# 3               2003               0                0                  0
# 4               1993               0                0                  0
# ..               ...             ...              ...                ...
# 995             1954               0                0                  0
# 996             1953               0                0                  0
# 997             1937               0                0                  0
# 998             1935               0                0                  0
# 999             1933               0                0                  0
#
#      Certificates_NC-17  Certificates_Not Rated  Certificates_PG  \
# ...

# %%
y = df['Rates']
y
# Out:
# 0      9.3
# 1      9.2
# 2      9.0
# 3      9.0
# 4      9.0
#       ...
# 995    7.6
# 996    7.6
# 997    7.6
# 998    7.6
# 999    7.6
# Name: Rates, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x = df.drop('Rates', axis=1)
y = df['Rates']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
from sklearn.linear_model import LinearRegression 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor 
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

models = [
     LinearRegression(),
     KNeighborsRegressor(),
     DecisionTreeRegressor(),
     SVR(),
     RandomForestRegressor(), 
     XGBRegressor()
]

for model in models:  
     print(model)
     model.fit(x_train, y_train)
     y_pred = model.predict(x_test)
     print(f'R2: {r2_score(y_test, y_pred) * 100}')
     print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
     print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}\n---------')
# Out:
# LinearRegression()
# R2: -8.318391847107762e+30
# MAE: 22828676771032.02
# RMSE: 77155517893824.02
# ---------
# KNeighborsRegressor()
# R2: -84.71857358448382
# MAE: 0.30519999999999997
# RMSE: 0.3635821777810348
# ---------
# DecisionTreeRegressor()
# R2: -25.132748309205688
# MAE: 0.21449999999999997
# RMSE: 0.29924906014889996
# ---------
# SVR()
# R2: -2.6082613415684186
# MAE: 0.2172096609416613
# RMSE: 0.27098076711545416
# ---------
# RandomForestRegressor()
# R2: 24.439627466324165
# MAE: 0.18405499999999975
# RMSE: 0.23253822266457563
# ---------
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None,
#              enable_categorical=False, gamma=None, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
# ...
